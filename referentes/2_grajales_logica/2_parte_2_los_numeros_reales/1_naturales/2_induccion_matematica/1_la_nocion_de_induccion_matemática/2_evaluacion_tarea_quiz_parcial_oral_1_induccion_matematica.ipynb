# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/2_parte_2_los_numeros_reales/1_naturales/2_induccion_matematica/2_evaluacion_tarea_quiz_parcial_oral_1_induccion_matematica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/2_parte_2_los_numeros_reales/1_naturales/2_induccion_matematica/2_evaluacion_tarea_quiz_parcial_oral_1_induccion_matematica.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# # Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas y administración de empresas
#
# [Hábitos atómicos](https://github.com/marco-canas/habitos_atomicos/blob/main/13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos/1_13_como_dejar_de_postergar_usando_la_regla_de_los_dos_minutos.ipynb)

# %% [markdown]
# # Título de la clase: Realización evaluación oral, de Tareas en cuadernos Jupyter, Quiz o Parcial de selección múltiple o de preguntas cerradas.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * [Hipervínculo para el cuaderno de enseñanza]()
# 1. Evaluar las tareas realizadas de manera manúscrita
# 2. Evaluar las tareas realizadas en los cuadernos Jupyter. (Solo realizar la tercera parte de las tareas asignadas de manera manuscrita)
# 3. Evaluar con un quiz escrito
# 4. Evaluar con un parcial escrito.
# 5. Evaluar la capacidad de describir un problema y su solución de manera oral.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# # Diseño de evaluación oral de si se alcanzaron los objetivos de aprendizaje planteados
#
# * Describa verbalmente el objetivo de aprendizaje y evidencie de forma oral si lo logró o no.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# 1. ¿?
# 2. ¿?
# 3. ¿?
# 4. ¿?
# 5. ¿?

# %% [markdown]
# # Vocabulary
#
# 1. length: longitud
# 2. width: ancho.
#
# [length, width](https://voca.ro/1of14ffdXnZI)

# %%
# algoritmo para llamar a evaluación oral individual
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/fundamentos_aritmetica.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) 

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def eval_oral():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Se expresó bien y correco {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
#while lista_estudiantes:
#    eval_oral()
#    guardar_cambios()

# %% [markdown]
# # 1. Evaluar las tareas realizadas de manera manúscrita

# %%
# Tarea 1 de lectura y completación de ejemplos del texto guia 
# Consiste en la lectura y completación de un ejemplo del texto guía

import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles


nombre_tarea = 'Tarea_1_lectura_ejemplos_Lina_Grajales_naturales_induccion_matematica'
grupo_estudiantes = 'fundamentos_aritmetica'
nombre_texto_guia = 'Lina_Grajales'
pagina_y_seccion = 'Página_14_Parte_1'
numero_ejemplos_texto = 27
numero_ejemplos_asignados = 10

# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
examples = list(range(1, numero_ejemplos_texto))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(examples, numero_ejemplos_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Example" + str(i+1) for i in range(numero_ejemplos_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = nombre_tarea + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea 1 asignada: ", assignment_csv)
print('''Debe transcribir el ejemplo en su cuaderno manuscrito o Jupyter y completar los procedimientos
      Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio, 
      Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
       Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase  
      ''')
assignment_df
# Out:
# Tarea 1 asignada:  Tarea_1_lectura_ejemplos_Lina_Grajales_naturales_induccion_matematica_Lina_Grajales_Página_14_Parte_1.csv
# Debe transcribir el ejemplo en su cuaderno manuscrito o Jupyter y completar los procedimientos
#       Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio,
#       Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
#        Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase
#                               Student  Example1  Example2  Example3  Example4  \
# 0      BADEL CORRALES JHONATAN ANDRES         4         9        10        11
# 1           CAMPO DIAZ ALBERTO ANDRES         2         6         7        15
# 2                  CASTRO JULIO KEREN         2         4         8        10
# 3           DIAZ GUERRERO JUAN DANIEL        10        11        14        15
# 4            FRANCO BOHORQUEZ ESTEBAN         5         7         9        16
# 5             GOEZ MESA MIGUEL ANDRES         5         6         9        15
# 6     GONZALEZ BASILIO LUISA FERNANDA         4         5         8         9
# 7              GONZALEZ GANDIA YELENA         2         3         6         7
# 8          GUERRA MERCADO JUAN CAMILO         4         8        10        12
# 9     GUERRA VILLADIEGO ANDRES FELIPE         4         5        14        16
# 10          GUERRA YEPEZ DIEGO ANDRES         2         3        10        13
# 11          GUERRERO GUERRA JOSE LUIS         2         4         5         7
# 12       HERNANDEZ LUNA BEATRIZ ELENA         7        11        12        13
# 13       HERRERA CASTILLO LUKAS MATEO         4        12        13        14
# 14  MARTINEZ CASARRUBIA LUIS FERNANDO         3         6         8         9
# 15               MEDINA GUERRA MANUEL         2         3        10        13
# 16    MONTERROSA GUERRERO SAID ANDRES         4         5        11        13
# 17              MONTES VARGAS VALERIA         4         5         6         8
# 18        MORENO VILORIA ANDRES DAVID         8        10        11        12
# 19             RIVERA GUZMAN CRISTIAN         6         7        10        14
# 20    RODRIGUEZ RESTREPO HERMEN DAVID         3         4         6         7
# 21         RUIZ PAYARES EMIRO ENRIQUE         2         4        14        15
# 22         SAENZ ARROYO LILIANA LUCIA         4         6         8        11
# 23      TUTISTAR GARZON EDWIN ROLANDO         7         8        12        14
# 24            VILLEGAS SIERRA ALLYSON         3         7         8        10
#
#     Example5  Example6  Example7  Example8  Example9  Example10
# 0         15        19        20        21        22         24
# 1         16        17        18        19        22         27
# 2         11        14        16        20        25         26
# 3         16        17        18        20        24         27
# 4         17        19        22        24        25         26
# 5         17        18        20        23        24         26
# 6         12        13        19        23        26         27
# 7         10        11        21        23        24         26
# 8         15        16        20        23        24         27
# 9         20        21        23        24        25         26
# 10        14        18        19        21        23         26
# 11         9        10        11        17        21         23
# 12        16        17        18        21        22         24
# 13        16        19        21        23        26         27
# 14        10        11        13        15        16         27
# 15        17        22        24        25        26         27
# 16        16        19        20        21        22         25
# 17         9        11        12        16        17         27
# 18        15        17        21        22        24         26
# 19        16        20        21        23        24         25
# 20        11        16        22        23        25         26
# 21        16        20        22        25        26         27
# 22        15        19        22        23        25         26
# 23        15        17        18        21        26         27
# 24        16        18        23        24        25         27

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a PINEDA ROMERO YOSMERI...
# Cambios guardados en el archivo CSV.

# %%
# Tarea 2: Asignación de ejercicio
# Ejercicios para adquirir habilidades de solución de problemas

import pandas as pd
import numpy as np
import requests
np.random.seed(424)  # establecer semilla aleatoria para hacer los resultados reproducibles


nombre_tarea = 'Tarea_2_solucion_problemas'
grupo_estudiantes = 'fundamentos_aritmetica'
nombre_texto_guia = 'Lina_Grajales_Matemáticas_I'
pagina_y_seccion = 'Página_44_Parte_1'
numero_ejercicios_taller = 33
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejercicios_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea_2_solucion_de_problemas" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 2 Solución de problemas para adquirir la metodología: 
    Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio, 
    Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
    Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase 
      """, assignment_csv)
assignment_df
# Out:
# Tarea 2 Solución de problemas para adquirir la metodología:
#     Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio,
#     Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
#     Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase
#        tarea_2_solucion_de_problemas_Lina_Grajales_Matemáticas_I_Página_44_Parte_1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0      BADEL CORRALES JHONATAN ANDRES      4      7     11     16     21
# 1           CAMPO DIAZ ALBERTO ANDRES      2      5      9     10     12
# 2                  CASTRO JULIO KEREN      6      8     11     18     19
# 3           DIAZ GUERRERO JUAN DANIEL      4      8     12     14     15
# 4            FRANCO BOHORQUEZ ESTEBAN      4     10     12     15     16
# 5             GOEZ MESA MIGUEL ANDRES      7     10     11     15     21
# 6     GONZALEZ BASILIO LUISA FERNANDA      2      3      5     15     18
# 7              GONZALEZ GANDIA YELENA      3      6      8     10     13
# 8          GUERRA MERCADO JUAN CAMILO      7      9     10     15     18
# 9     GUERRA VILLADIEGO ANDRES FELIPE      7      8     10     14     15
# 10          GUERRA YEPEZ DIEGO ANDRES      4      5     13     17     18
# 11          GUERRERO GUERRA JOSE LUIS      7     10     11     13     17
# 12       HERNANDEZ LUNA BEATRIZ ELENA      2      7      8     12     16
# 13       HERRERA CASTILLO LUKAS MATEO      3      7      9     12     14
# 14  MARTINEZ CASARRUBIA LUIS FERNANDO      2      7      8     13     16
# 15               MEDINA GUERRA MANUEL      3      7     10     11     12
# 16    MONTERROSA GUERRERO SAID ANDRES      2      5      6     12     15
# 17              MONTES VARGAS VALERIA      2      9     11     12     18
# 18        MORENO VILORIA ANDRES DAVID      9     10     12     17     21
# 19             RIVERA GUZMAN CRISTIAN      2      4      7     13     15
# 20    RODRIGUEZ RESTREPO HERMEN DAVID      2      5      9     14     24
# 21         RUIZ PAYARES EMIRO ENRIQUE      2      3      5     13     14
# 22         SAENZ ARROYO LILIANA LUCIA      2      3     11     13     16
# 23      TUTISTAR GARZON EDWIN ROLANDO      6     12     13     14     16
# 24            VILLEGAS SIERRA ALLYSON      3      5      7     18     21
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0      23     24     26     27      32
# 1      13     19     26     28      32
# 2      20     22     27     28      29
# 3      16     19     26     29      31
# 4      18     21     23     29      31
# 5      23     24     28     29      32
# 6      19     24     27     28      30
# 7      14     15     21     23      25
# 8      21     23     31     32      33
# 9      18     19     23     28      32
# 10     21     22     24     28      32
# 11     18     20     29     30      33
# 12     17     22     24     25      31
# 13     19     20     25     27      28
# 14     17     18     19     23      30
# 15     13     18     19     25      32
# 16     22     24     25     27      29
# 17     20     23     24     26      29
# 18     23     24     28     29      31
# 19     17     20     22     28      33
# 20     26     27     28     31      32
# 21     15     20     22     26      29
# 22     18     20     26     28      29
# 23     22     25     26     29      31
# 24     23     26     29     31      33

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a PEREZ REYES IVAN DARIO...
# Cambios guardados en el archivo CSV.

# %%
# Tarea 3 para después de la clase: asignación de ejercicios de un seccion del texto guía

# Tarea para adquisición de habilidades solución, descripción y justificación


import pandas as pd
import numpy as np
import requests
np.random.seed(126)  # establecer semilla aleatoria para hacer los resultados reproducibles



nombre_tarea = 'Tarea_3_solucion_problemas_descripcion_justificacion'
grupo_estudiantes = 'fundamentos_aritmetica'
nombre_texto_guia = 'Lina_Grajales_Matemáticas_I'
pagina_y_seccion = 'Página_44_Parte_1'
numero_ejercicios_taller = 33
numero_de_ejercicios_asignados = 10


# Descargar la lista de  estudiantes
students_path = "/home/marco/Documentos/docencia/groups_list/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_path)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.sort(np.random.choice(exercises, numero_de_ejercicios_asignados, \
                                                replace = False)+ 1 )
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = nombre_tarea + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("""Tarea 3 Descripción y Justificación:
    Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio, 
    Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
    Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase 
       """, assignment_csv)
assignment_df
# Out:
# Tarea 3 Descripción y Justificación:
#     Se valora su tarea solo si incluye el enunciado o planteamiento del problema de cada ejercicio,
#     Si no incluye de la conclusión verbal de cada ejercicio, entonces no se le valora la tarea.
#     Esta tarea se valora solo si la presenta de manera manuscrita en su cuaderno de clase
#         Tarea_3_solucion_problemas_descripcion_justificacion_Lina_Grajales_Matemáticas_I_Página_44_Parte_1.csv
#                               Student  Exer1  Exer2  Exer3  Exer4  Exer5  \
# 0      BADEL CORRALES JHONATAN ANDRES      7      9     10     14     23
# 1           CAMPO DIAZ ALBERTO ANDRES      4      6      7      9     12
# 2                  CASTRO JULIO KEREN      4      5      7      9     17
# 3           DIAZ GUERRERO JUAN DANIEL      2      3      5      9     11
# 4            FRANCO BOHORQUEZ ESTEBAN      8     10     12     15     18
# 5             GOEZ MESA MIGUEL ANDRES      2      3      6      9     10
# 6     GONZALEZ BASILIO LUISA FERNANDA      4      6      8     11     12
# 7              GONZALEZ GANDIA YELENA      3      7      9     17     22
# 8          GUERRA MERCADO JUAN CAMILO      5     12     13     14     15
# 9     GUERRA VILLADIEGO ANDRES FELIPE     10     13     17     24     25
# 10          GUERRA YEPEZ DIEGO ANDRES      4      9     12     13     15
# 11          GUERRERO GUERRA JOSE LUIS      2     11     12     13     17
# 12       HERNANDEZ LUNA BEATRIZ ELENA      5      6      9     16     18
# 13       HERRERA CASTILLO LUKAS MATEO      3      5      7      8     10
# 14  MARTINEZ CASARRUBIA LUIS FERNANDO      3      4      5     12     13
# 15               MEDINA GUERRA MANUEL     10     17     18     22     25
# 16    MONTERROSA GUERRERO SAID ANDRES      2      9     12     15     20
# 17              MONTES VARGAS VALERIA      5      8      9     13     17
# 18        MORENO VILORIA ANDRES DAVID      2      3     13     14     19
# 19             RIVERA GUZMAN CRISTIAN      6      7     10     12     13
# 20    RODRIGUEZ RESTREPO HERMEN DAVID      2      3      5      7     11
# 21         RUIZ PAYARES EMIRO ENRIQUE      3     10     15     18     19
# 22         SAENZ ARROYO LILIANA LUCIA     10     12     17     21     22
# 23      TUTISTAR GARZON EDWIN ROLANDO      4      9     10     11     12
# 24            VILLEGAS SIERRA ALLYSON      4     10     16     21     24
#
#     Exer6  Exer7  Exer8  Exer9  Exer10
# 0      25     26     27     30      32
# 1      17     21     22     23      27
# 2      19     22     26     29      30
# 3      13     17     24     29      32
# 4      22     24     29     30      31
# 5      11     18     19     28      31
# 6      13     18     20     23      26
# 7      23     24     25     29      30
# 8      20     21     22     23      27
# 9      26     27     28     29      33
# 10     21     24     29     31      32
# 11     18     22     24     27      28
# 12     19     22     25     30      32
# 13     15     19     21     22      28
# 14     17     27     28     31      33
# 15     27     28     29     30      31
# 16     21     24     25     27      29
# 17     19     20     27     28      29
# 18     23     27     28     31      32
# 19     16     20     22     29      30
# 20     12     13     14     15      26
# 21     20     24     26     32      33
# 22     25     26     27     29      33
# 23     14     15     27     31      32
# 24     27     29     30     31      33

# %%
eval_oral()
guardar_cambios()
# Out:
# Llamando a MIRANDA MARTINEZ CARLOS ANDRES...
# Actualizado: MIRANDA MARTINEZ CARLOS ANDRES ahora tiene 0.31 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.

# %% [markdown]
# # 3. Evaluar con un quiz escrito

# %%
# definición de los parámetros personalizados para el quiz
import numpy as np 
import pandas as pd 

url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_vectorial.csv'

df = pd.read_csv(url)
#df.head()
#df.info()
df['Cedula'] = df.Cedula.astype(str)
#type(df.Cédula[0])
# tomar los seis primeros o los seis ultimos dígitos 
# para fomentar el trabajo concentrado en las pruebas escribas

seleccionar_primeros_seis_digitos_o_los_ultimos = True

indice_asociado_al_estudiante = 0

if seleccionar_primeros_seis_digitos_o_los_ultimos:
    seis_digitos_documento_identidad = df.Cedula.iloc[indice_asociado_al_estudiante][:6]
else:
    seis_digitos_documento_identidad = df.Cedula.iloc[indice_asociado_al_estudiante][-6:]    
df.Cedula.iloc[indice_asociado_al_estudiante], seis_digitos_documento_identidad
# Out:
# ('1193404816', '119340')

# %%
eval_oral()
guardar_cambios()

# %%
# Quiz escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_vectorial'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_5_2 y 5_4'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 3


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.sort(np.random.choice(numero_ejercicios_taller, \
                                    numero_de_ejercicios_asignados, \
                                        replace = False)+1) 
random_exercises
# Out:
# array([16, 29, 36])

# %% [markdown]
# # 4. Evaluar con un parcial escrito.

# %%
# definición de los parámetros personalizados para el parcial
import numpy as np 
import pandas as pd 

url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_vectorial.csv'

df = pd.read_csv(url)
#df.head()
#df.info()
df['Cedula'] = df.Cedula.astype(str)
#type(df.Cédula[0])
# tomar los seis primeros o los seis ultimos dígitos 
# para fomentar el trabajo concentrado en las pruebas escribas

seleccionar_primeros_seis_digitos_o_los_ultimos = True

indice_asociado_al_estudiante = 0

if seleccionar_primeros_seis_digitos_o_los_ultimos:
    seis_digitos_documento_identidad = df.Cedula.iloc[indice_asociado_al_estudiante][:6]
else:
    seis_digitos_documento_identidad = df.Cedula.iloc[indice_asociado_al_estudiante][-6:]    
df.Cedula.iloc[indice_asociado_al_estudiante], seis_digitos_documento_identidad
# Out:
# ('1193404816', '119340')

# %%
# Parcial escrito: 



import pandas as pd
import numpy as np
import requests
np.random.seed(1213)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'calculo_integral'
nombre_texto_guia = 'Purcell'
pagina_y_seccion = 'Página_202_Sección_3.8'
numero_ejercicios_taller = 54
numero_de_ejercicios_asignados = 5


# Asignar ejercicios aleatorios a cada estudiante

random_exercises = np.sort(np.random.choice(numero_ejercicios_taller, \
                                    numero_de_ejercicios_asignados, replace = False)+1) 
random_exercises
# Out:
# array([ 1, 16, 29, 34, 36])

# %% [markdown]
# ## Diseño de parcial sobre números naturales
#
# 1. Punto teórico (valor 20 puntos)
#      - ¿qué es un poligono? Ejemplifique y justifique su ejemplo.
#      - ¿qué es un polígono convexo? Ejemplifique y justifique
#      - ¿Qué es un polígono no convexo? Ejemplifique y justifique su ejemplo.
#      - ¿Qué es un número primo? Ejemplifique y justifica
#      - ¿qué son números primos relativos? Ejemplifique y justifique su ejemplo.
#      - ¿Qué es una fracción irreducible? Ejemplifique y justifique su ejemplo.
#      - ¿Qué son fracciones equivalentes? Ejemplifique y justifique su ejemplo.
#      - ¿Qué es una fracción reducible? Ejemplifique y justifique su ejemplo.

# %% [markdown]
# 2. Valor (20 puntos) Demostración por método de inducción matemática
#
#    $$ \text{Todo polígono convexo de $n$ lados se cumple que: la suma de la medida de sus ángulos es igual a} (n-2)180^{o} $$
#
#    1. Enuncie y verifique el paso base.
#    2. Enuncie el supuesto o hipótesis inductiva
#    3. Enuncie la tesis inductiva.

# %% [markdown]
# ### Solución ejemplo del punto 2
#
# 1. Enunciación del paso base:
#
# Mostremos que para $n = 3$, la función proposicional se satisface, es decir, mostremos que en cualquier triángulo se cumple que la suma de las medidas de sus ángulos es igual a $(n-2)180$.
#
# En efecto, del quinto postulado de Euclides, se infiere que la suma de las medidas de los ángulos de un triángulo es $180^{o}$ y
#
# $$ 180 = (n-2)180 = (3-2)180 $$

# %%
eval_oral()
guardar_cambios()

# %% [markdown]
# # 5. Evaluación oral
# ## 5. Evaluar la capacidad de describir un problema y su solución de manera oral.
#
# 1. Evaluaremos la capacidad de describir cada uno de los pasos o fases para resolver un problema (Es decir, se pedirá al estudiante que describa la metodología de solución de un problema dado).

# %%
# algoritmo para llamar a evaluación oral individual
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde la URL
path = '/home/marco/Documentos/docencia/groups_list/fundamentos_aritmetica.csv'
estudiantes = pd.read_csv(path)
estudiantes['Parcial'] = estudiantes['Parcial'].astype(float) 

# Convertir la columna 'Nombre' a una lista de Python
lista_estudiantes = estudiantes['Nombre'].tolist()

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def eval_oral():
    if lista_estudiantes:
        estudiante_aleatorio = np.random.choice(lista_estudiantes)
        print(f"Llamando a {estudiante_aleatorio}...")
        asistencia = input(f"¿Se expresó bien y correco {estudiante_aleatorio}? (s/n): ").strip().lower()
        
        if asistencia == 's':
            # Obtener el índice del estudiante en el DataFrame
            indice = estudiantes[estudiantes['Nombre'] == estudiante_aleatorio].index[0]
            # Incrementar su valor en la columna 'Parcial'
            estudiantes.at[indice, 'Parcial'] += 0.1
            print(f"Actualizado: {estudiante_aleatorio} ahora tiene {estudiantes.at[indice, 'Parcial']} en la columna 'Parcial'.")
        
        lista_estudiantes.remove(estudiante_aleatorio)
    else:
        print("Se han llamado a todos los estudiantes del grupo completo.")

# Guardar los cambios en el archivo CSV
def guardar_cambios():
    estudiantes.to_csv(path, index=False)
    print("Cambios guardados en el archivo CSV.")

# Ejemplo de uso
while lista_estudiantes:
    eval_oral()
    guardar_cambios()
# Out:
# Llamando a FRANCO BOHORQUEZ ESTEBAN...
# Cambios guardados en el archivo CSV.
# Llamando a CASTRO JULIO KEREN...
# Actualizado: CASTRO JULIO KEREN ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a GUERRERO GUERRA JOSE LUIS...
# Actualizado: GUERRERO GUERRA JOSE LUIS ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a TUTISTAR GARZON EDWIN ROLANDO...
# Cambios guardados en el archivo CSV.
# Llamando a GONZALEZ GANDIA YELENA...
# Cambios guardados en el archivo CSV.
# Llamando a MEDINA GUERRA MANUEL...
# Actualizado: MEDINA GUERRA MANUEL ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a MONTES VARGAS VALERIA...
# Cambios guardados en el archivo CSV.
# Llamando a VILLEGAS SIERRA ALLYSON...
# Cambios guardados en el archivo CSV.
# Llamando a MONTERROSA GUERRERO SAID ANDRES...
# Cambios guardados en el archivo CSV.
# Llamando a SAENZ ARROYO LILIANA LUCIA...
# Cambios guardados en el archivo CSV.
# Llamando a BADEL CORRALES JHONATAN ANDRES...
# Actualizado: BADEL CORRALES JHONATAN ANDRES ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a HERRERA CASTILLO LUKAS MATEO...
# Actualizado: HERRERA CASTILLO LUKAS MATEO ahora tiene 0.2 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a RUIZ PAYARES EMIRO ENRIQUE...
# Cambios guardados en el archivo CSV.
# Llamando a MORENO VILORIA ANDRES DAVID...
# Cambios guardados en el archivo CSV.
# Llamando a GOEZ MESA MIGUEL ANDRES...
# Cambios guardados en el archivo CSV.
# Llamando a GONZALEZ BASILIO LUISA FERNANDA...
# Actualizado: GONZALEZ BASILIO LUISA FERNANDA ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a MARTINEZ CASARRUBIA LUIS FERNANDO...
# Actualizado: MARTINEZ CASARRUBIA LUIS FERNANDO ahora tiene 0.2 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a GUERRA VILLADIEGO ANDRES FELIPE...
# Actualizado: GUERRA VILLADIEGO ANDRES FELIPE ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a HERNANDEZ LUNA BEATRIZ ELENA...
# Actualizado: HERNANDEZ LUNA BEATRIZ ELENA ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a RIVERA GUZMAN CRISTIAN...
# Actualizado: RIVERA GUZMAN CRISTIAN ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a DIAZ GUERRERO JUAN DANIEL...
# Actualizado: DIAZ GUERRERO JUAN DANIEL ahora tiene 0.2 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a GUERRA MERCADO JUAN CAMILO...
# Actualizado: GUERRA MERCADO JUAN CAMILO ahora tiene 0.30000000000000004 en la columna 'Parcial'.
# Cambios guardados en el archivo CSV.
# Llamando a GUERRA YEPEZ DIEGO ANDRES...
# Cambios guardados en el archivo CSV.
# Llamando a CAMPO DIAZ ALBERTO ANDRES...
# Cambios guardados en el archivo CSV.
# Llamando a RODRIGUEZ RESTREPO HERMEN DAVID...
# Cambios guardados en el archivo CSV.

# %% [markdown]
# # Autoevaluación

# %%
import csv

def recolectar_datos_autoavaluacion():
    # Definir el nombre del archivo CSV
    nombre_archivo = 'autoevaluacion_estudiantes.csv'
    
    # Definir los encabezados para el archivo CSV
    encabezados = ['Nombre', 'Fortalezas', 'Áreas de Mejora']
    
    # Solicitar los datos del estudiante
    nombre = input("Ingrese su nombre: ")
    fortalezas = input("Describa sus fortalezas: ")
    areas_mejora = input("Describa las áreas en las que necesita mejorar: ")
    
    # Crear una lista con los datos del estudiante
    datos = [nombre, fortalezas, areas_mejora]
    
    # Abrir el archivo CSV para agregar los datos
    with open(nombre_archivo, mode='a', newline='') as archivo_csv:
        escritor_csv = csv.writer(archivo_csv)
        
        # Verificar si el archivo está vacío para escribir los encabezados
        archivo_csv.seek(0, 2)  # Mover el cursor al final del archivo
        if archivo_csv.tell() == 0:  # Verificar si el archivo está vacío
            escritor_csv.writerow(encabezados)
        
        # Escribir los datos en el archivo CSV
        escritor_csv.writerow(datos)
    
    print("La autoevaluación se ha guardado correctamente.")

# Ejecutar la función para recolectar datos
recolectar_datos_autoavaluacion()
# Out:
# La autoevaluación se ha guardado correctamente.

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# # FODA del grupo y del profesor
#
# * F: Fortalezas
# * O: Oportunidades
# * D: Dificultades
# * A: Amenazas.

# %% [markdown]
# ## ¿Cómo se sintió en este espacio de enseñanza y aprendizaje?
#
# !Dios te bendiga¡

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://github.com/marco-canas/fundamentos_de_la_aritmetica/blob/main/referentes/2_grajales_logica/grajales_lina_matemticas.pdf)
#
# * Duval, R. (2004). Semiosis y pensamiento humano: registros semióticos y aprendizajes intelectuales. Universidad del Valle.
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](https://github.com/marco-canas/fundamentos_logica/blob/main/referentes/2_uzcategui/uscategui.pdf)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/chollet/Fran%C3%A7ois%20Chollet%20-%20Deep%20Learning%20with%20Python-Manning%20(2018).pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/geron/Hands-On%20Machine%20Learning-3nd_Edition(2022).pdf)
#
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/2_referentes/mckinney/Wes_McKinney.pdf)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()
